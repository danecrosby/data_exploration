# %%
# Pandas is used for data manipulation
import pandas as pd
# Read in data and display first 5 rows
dogs = pd.read_csv('D:/projects/20151001hundehalter.csv')
dogs.head(5)
# Out:
#    HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER              RASSE1  \
# 0        126  51-60          m         9.0           92.0       Welsh Terrier
# 1        574  61-70          w         2.0           23.0       Cairn Terrier
# 2        695  41-50          m         6.0           63.0  Labrador Retriever
# 3        893  61-70          w         7.0           71.0     Mittelschnauzer
# 4       1177  51-60          m        10.0          102.0            Shih Tzu
#
#   RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  GEBURTSJAHR_HUND  \
# 0              NaN    NaN               NaN         K              2011
# 1              NaN    NaN               NaN         K              2002
# 2              NaN    NaN               NaN         I              2012
# 3              NaN    NaN               NaN         I              2010
# 4              NaN    NaN               NaN         K              2011
#
#   GESCHLECHT_HUND     HUNDEFARBE
# 0               w  schwarz/braun
# 1               w        brindle
# 2               w          braun
# 3               w        schwarz
# 4               m  schwarz/weiss

# %%
print('The shape of our features is:', dogs.shape)
# Out:
# The shape of our features is: (6980, 13)

# %%
dogs = dogs[["HALTER_ID", 'ALTER', 'GESCHLECHT', 'STADTKREIS', 'STADTQUARTIER','RASSE1','GESCHLECHT_HUND','HUNDEFARBE']]

# %%
dogs = dogs.rename(columns={'HALTER_ID': 'HOLDER_ID',
                            'ALTER': 'AGE',
                            'GESCHLECHT': 'GENDER',
                            'STADTKREIS': 'CITY DISTRICT',
                            'STADTQUARTIER': 'CITY QUARTER',
                            'RASSE1':'BREED',
                            'GESCHLECHT_HUND': 'DOG GENDER',
                            'HUNDEFARBE': 'COLOR',})
dogs.head(5)
# Out:
#    HOLDER_ID    AGE GENDER  CITY DISTRICT  CITY QUARTER               BREED  \
# 0        126  51-60      m            9.0          92.0       Welsh Terrier
# 1        574  61-70      w            2.0          23.0       Cairn Terrier
# 2        695  41-50      m            6.0          63.0  Labrador Retriever
# 3        893  61-70      w            7.0          71.0     Mittelschnauzer
# 4       1177  51-60      m           10.0         102.0            Shih Tzu
#
#   DOG GENDER          COLOR
# 0          w  schwarz/braun
# 1          w        brindle
# 2          w          braun
# 3          w        schwarz
# 4          m  schwarz/weiss

# %%
colors = dogs.groupby('COLOR').size().sort_values(ascending=False)
colors.head(100)
# Out:
# COLOR
# schwarz                   763
# tricolor                  669
# weiss                     544
# braun                     530
# schwarz/weiss             443
#                          ...
# braun schwarz gestromt      5
# steelblue                   5
# grau/weiss/schwarz          5
# gold/weiss                  5
# mahagoni                    5
# Length: 100, dtype: int64

# %%
from Levenshtein import distance as levenshtein_distance

a = "grau/weiss/schwarz"
b = "grau/weiss"
seq=levenshtein_distance(a,b)
print(seq)

print(colors.index)
# Out:
# 8
# Index(['schwarz', 'tricolor', 'weiss', 'braun', 'schwarz/weiss',
#        'schwarz/braun', 'beige', 'braun/weiss', 'weiss/braun', 'black/tan',
#        ...
#        'grau/weiss/braun', 'braun/weiss/beige', 'grau/weiss/beige',
#        'grau/braun/weiss', 'rot/grau', 'gemischt', 'silber/weiss',
#        'gelb/braun', 'creme/schwarz', 'Harlekin'],
#       dtype='object', name='COLOR', length=169)

# %%
lev = pd.DataFrame(index = colors.index, columns = colors.index)

# %%
for x in colors.index:
    for y in colors.index:
        lev.loc[x,y] = levenshtein_distance(x,y)
                        
lev.head(10)
# Out:
# COLOR         schwarz tricolor weiss braun schwarz/weiss schwarz/braun beige  \
# COLOR
# schwarz             0        7     7     6             6             6     7
# tricolor            7        0     7     7            12            12     7
# weiss               7        7     0     5             8            12     3
# braun               6        7     5     0            12             8     4
# schwarz/weiss       6       12     8    12             0             5    11
# schwarz/braun       6       12    12     8             5             0    12
# beige               7        7     3     4            11            12     0
# braun/weiss        10       10     6     6             6            11     8
# weiss/braun         9        9     6     6            12             7     9
# black/tan           8        8     9     6            11             9     8
#
# COLOR         braun/weiss weiss/braun black/tan  ... grau/weiss/braun  \
# COLOR                                            ...
# schwarz                10           9         8  ...               14
# tricolor               10           9         8  ...               13
# weiss                   6           6         9  ...               11
# braun                   6           6         6  ...               11
# schwarz/weiss           6          12        11  ...               12
# schwarz/braun          11           7         9  ...                9
# beige                   8           9         8  ...               14
# braun/weiss             0          10         8  ...                8
# weiss/braun            10           0         8  ...                5
# black/tan               8           8         0  ...               12
#
# COLOR         braun/weiss/beige grau/weiss/beige grau/braun/weiss rot/grau  \
# COLOR
# schwarz                      16               15               15        7
# tricolor                     15               14               15        8
# weiss                        12               11               11        8
# braun                        12               13               11        6
# schwarz/weiss                12               12                9       12
# schwarz/braun                14               13               12        9
# beige                        12               11               13        7
# braun/weiss                   6                8                5        9
# weiss/braun                  10                9               11        7
# black/tan                    14               14               13        8
#
# COLOR         gemischt silber/weiss gelb/braun creme/schwarz Harlekin
# COLOR
# schwarz              8           10          9             6        8
# tricolor             8           11         10            10        8
# weiss                5            7          9            11        7
# braun                8           10          5            11        6
# schwarz/weiss       13            5         12            12       10
# schwarz/braun       13           10          7            12       10
# beige                6            9          9            12        7
# braun/weiss         11            6         10            11        9
# weiss/braun          9           11          4            10       10
# black/tan            9           10          8            11        7
#
# [10 rows x 169 columns]

# %%
blacklist = lev["rot/schwarz"].sort_values()
blacklist.head(30)
# Out:
# COLOR
# rot/schwarz           0
# gold/schwarz          3
# grau/schwarz          3
# schwarz               4
# gelb/schwarz          4
# braun/schwarz         4
# creme/schwarz         4
# rot/grau/schwarz      5
# weiss/schwarz         5
# beige/schwarz         5
# rot/grau              6
# rot/braun             6
# rot/weiss             7
# rot/beige             7
# rotbraun              7
# gemischt              8
# rot                   8
# rotblond              8
# schwarz/loh           8
# tricolor              8
# schwarz/rot           8
# grau/silber           8
# hirschrot             8
# grau/braun            9
# choco                 9
# schwarz/gelb          9
# braun/schwarz/grau    9
# bicolor               9
# goldbraun             9
# weiss/grau            9
# Name: rot/schwarz, dtype: object

# %%
from difflib import SequenceMatcher

matcher = pd.DataFrame(index = colors.index, columns = colors.index)

# %%
for x in colors.index:
    for y in colors.index:
        matcher.loc[x,y] = SequenceMatcher(None, x, y).ratio()
                        
matcher.head(10)
# Out:
# COLOR           schwarz  tricolor     weiss     braun schwarz/weiss  \
# COLOR
# schwarz             1.0  0.266667  0.166667  0.166667           0.7
# tricolor       0.133333       1.0  0.153846  0.153846      0.190476
# weiss          0.166667  0.153846       1.0       0.0      0.555556
# braun          0.166667  0.153846       0.0       1.0      0.111111
# schwarz/weiss       0.7  0.190476  0.555556  0.111111           1.0
# schwarz/braun       0.7  0.190476  0.111111  0.555556      0.615385
# beige               0.0  0.153846       0.4       0.2      0.222222
# braun/weiss    0.111111  0.210526     0.625     0.625      0.583333
# weiss/braun    0.222222  0.210526     0.625     0.625      0.416667
# black/tan         0.125  0.117647       0.0  0.428571      0.181818
#
# COLOR         schwarz/braun     beige braun/weiss weiss/braun black/tan  ...  \
# COLOR                                                                    ...
# schwarz                 0.7       0.0    0.111111    0.222222      0.25  ...
# tricolor           0.190476  0.153846    0.210526    0.105263  0.117647  ...
# weiss              0.111111       0.4       0.625       0.625       0.0  ...
# braun              0.555556       0.2       0.625       0.625  0.428571  ...
# schwarz/weiss      0.615385  0.222222    0.583333    0.416667  0.181818  ...
# schwarz/braun           1.0  0.111111    0.416667    0.583333  0.272727  ...
# beige              0.111111       1.0       0.375        0.25  0.142857  ...
# braun/weiss        0.416667     0.375         1.0    0.454545       0.3  ...
# weiss/braun        0.583333      0.25    0.454545         1.0       0.3  ...
# black/tan          0.272727  0.142857         0.3         0.3       1.0  ...
#
# COLOR         grau/weiss/braun braun/weiss/beige grau/weiss/beige  \
# COLOR
# schwarz               0.173913          0.083333         0.086957
# tricolor                  0.25              0.16         0.166667
# weiss                  0.47619          0.454545          0.47619
# braun                  0.47619          0.454545         0.285714
# schwarz/weiss         0.482759          0.466667         0.482759
# schwarz/braun         0.482759          0.333333         0.206897
# beige                 0.190476          0.454545          0.47619
# braun/weiss           0.666667          0.785714         0.666667
# weiss/braun           0.814815               0.5         0.518519
# black/tan                 0.24          0.230769             0.08
#
# COLOR         grau/braun/weiss  rot/grau  gemischt silber/weiss gelb/braun  \
# COLOR
# schwarz               0.086957  0.133333       0.4     0.210526   0.117647
# tricolor              0.166667      0.25     0.125          0.2   0.111111
# weiss                  0.47619       0.0  0.461538     0.588235   0.133333
# braun                  0.47619  0.461538       0.0     0.235294   0.666667
# schwarz/weiss         0.551724  0.095238  0.285714         0.64   0.086957
# schwarz/braun         0.482759   0.47619  0.285714         0.16   0.521739
# beige                 0.285714  0.153846  0.307692     0.352941   0.266667
# braun/weiss           0.814815  0.315789  0.315789     0.695652    0.47619
# weiss/braun           0.444444  0.421053  0.315789     0.434783   0.666667
# black/tan                 0.24  0.117647  0.235294     0.190476   0.315789
#
# COLOR         creme/schwarz  Harlekin
# COLOR
# schwarz                 0.7  0.266667
# tricolor           0.285714      0.25
# weiss              0.111111  0.307692
# braun              0.222222  0.307692
# schwarz/weiss      0.538462  0.380952
# schwarz/braun      0.538462  0.285714
# beige              0.222222  0.307692
# braun/weiss        0.166667  0.210526
# weiss/braun        0.166667  0.315789
# black/tan          0.090909  0.352941
#
# [10 rows x 169 columns]

# %%
mblacklist = matcher["rot/schwarz"].sort_values(ascending = False)
mblacklist.head(20)
# Out:
# COLOR
# rot/schwarz                 1.0
# rot/grau/schwarz       0.814815
# gold/schwarz           0.782609
# grau/schwarz           0.782609
# schwarz                0.777778
# braun/schwarz              0.75
# creme/schwarz              0.75
# gelb/schwarz           0.695652
# weiss/schwarz          0.666667
# beige/schwarz          0.666667
# schwarz/loh            0.636364
# schwarz/rot            0.636364
# braun/schwarz/grau      0.62069
# grau/braun/schwarz      0.62069
# grau/weiss/schwarz      0.62069
# schwarz/gold           0.608696
# schwarz/grau           0.608696
# schwarz/gelb           0.608696
# beige/braun/schwarz         0.6
# braun/weiss/schwarz         0.6
# Name: rot/schwarz, dtype: object

# %%
#Function that compares every permuation of the words with slashes
import itertools


def test_permumatch(str1,str2):
    for x in itertools.permutations(str1.split('/')):
        for y in itertools.permutations(str2.split('/')):
            xjoin = '/'.join(x)
            yjoin = '/'.join(y)
            print(xjoin , yjoin , SequenceMatcher(None, xjoin, yjoin).ratio())

# %%
test_permumatch("red/blue/green","blue/red/green")
# Out:
# red/blue/green blue/red/green 0.7142857142857143
# red/blue/green blue/green/red 0.7142857142857143
# red/blue/green red/blue/green 1.0
# red/blue/green red/green/blue 0.6428571428571429
# red/blue/green green/blue/red 0.7142857142857143
# red/blue/green green/red/blue 0.5714285714285714
# red/green/blue blue/red/green 0.6428571428571429
# red/green/blue blue/green/red 0.6428571428571429
# red/green/blue red/blue/green 0.6428571428571429
# red/green/blue red/green/blue 1.0
# red/green/blue green/blue/red 0.7142857142857143
# red/green/blue green/red/blue 0.7142857142857143
# blue/red/green blue/red/green 1.0
# blue/red/green blue/green/red 0.7142857142857143
# blue/red/green red/blue/green 0.7142857142857143
# blue/red/green red/green/blue 0.6428571428571429
# blue/red/green green/blue/red 0.5714285714285714
# blue/red/green green/red/blue 0.5
# blue/green/red blue/red/green 0.7142857142857143
# blue/green/red blue/green/red 1.0
# blue/green/red red/blue/green 0.7142857142857143
# blue/green/red red/green/blue 0.6428571428571429
# blue/green/red green/blue/red 0.6428571428571429
# blue/green/red green/red/blue 0.6428571428571429
# green/red/blue blue/red/green 0.35714285714285715
# green/red/blue blue/green/red 0.6428571428571429
# green/red/blue red/blue/green 0.5714285714285714
# green/red/blue red/green/blue 0.7142857142857143
# green/red/blue green/blue/red 0.7142857142857143
# green/red/blue green/red/blue 1.0
# green/blue/red blue/red/green 0.5714285714285714
# green/blue/red blue/green/red 0.6428571428571429
# green/blue/red red/blue/green 0.7142857142857143
# green/blue/red red/green/blue 0.7142857142857143
# green/blue/red green/blue/red 1.0
# green/blue/red green/red/blue 0.7142857142857143

# %%
#Function that compares every permuation of the words with slashes
import itertools


def permumatch(str1,str2):
    best_match = 0
    for x in itertools.permutations(str1.split('/')):
        for y in itertools.permutations(str2.split('/')):
            xjoin = '/'.join(x)
            yjoin = '/'.join(y)
            match = SequenceMatcher(None, xjoin, yjoin).ratio()
            if match > best_match:
                best_match = match
                
    return best_match

# %%
print(permumatch("blue/green/red","blue/red/green"))
# Out:
# 1.0

# %%
from difflib import SequenceMatcher

supermatcher = pd.DataFrame(index = colors.index, columns = colors.index)

for x in colors.index:
    for y in colors.index:
        supermatcher.loc[x,y] = permumatch(x,y)
                        
supermatcher.head(10)
# Out:
# COLOR           schwarz  tricolor     weiss     braun schwarz/weiss  \
# COLOR
# schwarz             1.0  0.266667  0.166667  0.166667           0.7
# tricolor       0.133333       1.0  0.153846  0.153846      0.190476
# weiss          0.166667  0.153846       1.0         0      0.555556
# braun          0.166667  0.153846         0       1.0      0.111111
# schwarz/weiss       0.7  0.285714  0.555556  0.111111           1.0
# schwarz/braun       0.7  0.285714  0.111111  0.555556      0.615385
# beige                 0  0.153846       0.4       0.2      0.222222
# braun/weiss    0.222222  0.210526     0.625     0.625      0.583333
# weiss/braun    0.222222  0.210526     0.625     0.625      0.583333
# black/tan         0.125  0.235294         0  0.428571      0.181818
#
# COLOR         schwarz/braun     beige braun/weiss weiss/braun black/tan  ...  \
# COLOR                                                                    ...
# schwarz                 0.7         0    0.222222    0.222222      0.25  ...
# tricolor           0.285714  0.153846    0.210526    0.210526  0.235294  ...
# weiss              0.111111       0.4       0.625       0.625         0  ...
# braun              0.555556       0.2       0.625       0.625  0.428571  ...
# schwarz/weiss      0.615385  0.222222    0.583333    0.583333  0.181818  ...
# schwarz/braun           1.0  0.111111    0.583333    0.583333  0.363636  ...
# beige              0.111111       1.0       0.375       0.375  0.142857  ...
# braun/weiss        0.583333     0.375         1.0         1.0       0.3  ...
# weiss/braun        0.583333     0.375         1.0         1.0       0.3  ...
# black/tan          0.363636  0.142857         0.3         0.3       1.0  ...
#
# COLOR         grau/weiss/braun braun/weiss/beige grau/weiss/beige  \
# COLOR
# schwarz                0.26087          0.166667         0.173913
# tricolor                  0.25              0.16         0.166667
# weiss                  0.47619          0.454545          0.47619
# braun                  0.47619          0.454545         0.380952
# schwarz/weiss         0.551724          0.466667         0.482759
# schwarz/braun         0.551724          0.466667         0.413793
# beige                 0.380952          0.454545          0.47619
# braun/weiss           0.814815          0.785714         0.740741
# weiss/braun           0.814815          0.785714         0.740741
# black/tan                 0.32          0.307692             0.24
#
# COLOR         grau/braun/weiss  rot/grau  gemischt silber/weiss gelb/braun  \
# COLOR
# schwarz                0.26087  0.266667       0.4     0.210526   0.117647
# tricolor                  0.25      0.25     0.125          0.2   0.222222
# weiss                  0.47619         0  0.461538     0.588235   0.133333
# braun                  0.47619  0.461538         0     0.235294   0.666667
# schwarz/weiss         0.551724  0.190476   0.47619         0.64    0.26087
# schwarz/braun         0.551724   0.47619  0.285714         0.32   0.521739
# beige                 0.380952  0.153846  0.307692     0.352941        0.4
# braun/weiss           0.814815  0.421053  0.315789     0.695652   0.666667
# weiss/braun           0.814815  0.421053  0.315789     0.695652   0.666667
# black/tan                 0.32  0.352941  0.235294     0.190476   0.421053
#
# COLOR         creme/schwarz  Harlekin
# COLOR
# schwarz                 0.7  0.266667
# tricolor           0.285714      0.25
# weiss              0.222222  0.307692
# braun              0.222222  0.307692
# schwarz/weiss      0.692308  0.380952
# schwarz/braun      0.692308  0.285714
# beige              0.222222  0.307692
# braun/weiss            0.25  0.315789
# weiss/braun            0.25  0.315789
# black/tan          0.272727  0.352941
#
# [10 rows x 169 columns]

# %%
superblacklist = supermatcher["rot/schwarz"].sort_values(ascending = False)
superblacklist.head(20)
# Out:
# COLOR
# rot/schwarz                    1.0
# schwarz/rot                    1.0
# schwarz/loh               0.818182
# rot/grau/schwarz          0.814815
# schwarz/braun/rot         0.785714
# schwarz/gold              0.782609
# grau/schwarz              0.782609
# schwarz/grau              0.782609
# gold/schwarz              0.782609
# schwarz                   0.777778
# braun/schwarz                 0.75
# schwarz/braun                 0.75
# creme/schwarz                 0.75
# schwarz gestromt          0.740741
# schwarz/silber                0.72
# gelb/schwarz              0.695652
# schwarz/gelb              0.695652
# schwarz/braun gestromt    0.666667
# schwarz/beige             0.666667
# weiss/schwarz             0.666667
# Name: rot/schwarz, dtype: object

# %%
my_series = dogs.duplicated()
my_series
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6975    False
# 6976    False
# 6977    False
# 6978    False
# 6979    False
# Length: 6980, dtype: bool

# %%
num_dupes = 0
my_series = dogs.duplicated()
for x in dogs.index:
    if my_series[x]:
        num_dupes+= 1
        
print("There are", num_dupes, "duplicate entries")
# Out:
# There are 82 duplicate entries

# %%
#unduped_dogs = dogs.drop_duplicates(subset=['HOLDER_ID'])
#unduped_dogs

unduped_dogs = dogs.drop_duplicates()

# %%
#Create function to convert a string of form 'x-y' into a float = average(x,y)
import statistics 

def average_age(txt):
    ages = [int(s) for s in txt.split('-') if s.isdigit()]
    return statistics.mean(ages)

print(average_age("12-18-12-a-234-a-b"))
# Out:
# 69

# %%
#Make sure AGE values have values and are not empty
dogs = dogs[dogs['AGE'].notnull()]
dogs
# Out:
#       HOLDER_ID    AGE GENDER  CITY DISTRICT  CITY QUARTER  \
# 0           126  51-60      m            9.0          92.0
# 1           574  61-70      w            2.0          23.0
# 2           695  41-50      m            6.0          63.0
# 3           893  61-70      w            7.0          71.0
# 4          1177  51-60      m           10.0         102.0
# ...         ...    ...    ...            ...           ...
# 6975     128471  21-30      w            8.0          83.0
# 6976     128471  21-30      w            8.0          83.0
# 6977     128479  51-60      w            6.0          63.0
# 6978     128482  21-30      w            9.0          91.0
# 6979     128485  21-30      w            7.0          74.0
#
#                    BREED DOG GENDER               COLOR
# 0          Welsh Terrier          w       schwarz/braun
# 1          Cairn Terrier          w             brindle
# 2     Labrador Retriever          w               braun
# 3        Mittelschnauzer          w             schwarz
# 4               Shih Tzu          m       schwarz/weiss
# ...                  ...        ...                 ...
# 6975     Tibetan Spaniel          w         braun/beige
# 6976          Rottweiler          m         schwarz/rot
# 6977   Lagotto Romagnolo          m          weiss/grau
# 6978   Yorkshire Terrier          w  schwarz/braun/grau
# 6979       Magyar Viszla          w                gelb
#
# [6978 rows x 8 columns]

# %%
averaged_dogs = dogs['AGE'].apply(lambda x: average_age(x))
dogs['AGE'] = averaged_dogs
dogs
# Out:
#       HOLDER_ID   AGE GENDER  CITY DISTRICT  CITY QUARTER               BREED  \
# 0           126  55.5      m            9.0          92.0       Welsh Terrier
# 1           574  65.5      w            2.0          23.0       Cairn Terrier
# 2           695  45.5      m            6.0          63.0  Labrador Retriever
# 3           893  65.5      w            7.0          71.0     Mittelschnauzer
# 4          1177  55.5      m           10.0         102.0            Shih Tzu
# ...         ...   ...    ...            ...           ...                 ...
# 6975     128471  25.5      w            8.0          83.0     Tibetan Spaniel
# 6976     128471  25.5      w            8.0          83.0          Rottweiler
# 6977     128479  55.5      w            6.0          63.0   Lagotto Romagnolo
# 6978     128482  25.5      w            9.0          91.0   Yorkshire Terrier
# 6979     128485  25.5      w            7.0          74.0       Magyar Viszla
#
#      DOG GENDER               COLOR
# 0             w       schwarz/braun
# 1             w             brindle
# 2             w               braun
# 3             w             schwarz
# 4             m       schwarz/weiss
# ...         ...                 ...
# 6975          w         braun/beige
# 6976          m         schwarz/rot
# 6977          m          weiss/grau
# 6978          w  schwarz/braun/grau
# 6979          w                gelb
#
# [6978 rows x 8 columns]
